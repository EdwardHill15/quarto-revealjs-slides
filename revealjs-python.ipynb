# %% [markdown]
# 1. Title Slide (Markdown cell)
#
# Set this cell type to Slide

# %% [markdown]
# # My Reveal.js Presentation
# ### Built in JupyterLab with RISE
#
# Author: Ed Hillenaar

# %%
{"slideshow": {"slide_type": "slide"}}
# Out:
# {'slideshow': {'slide_type': 'slide'}}

# %% [markdown]
# 2. Introduction (Markdown cell)
#
# Set to Slide

# %% [markdown]
# ## Introduction
#
# This is a simple reveal.js slideshow created from a Jupyter notebook.
#
# We are using:
# - JupyterLab
# - RISE (Reveal.js integration)

# %%
{"slideshow": {"slide_type": "slide"}}

# %% [markdown]
# 3. Code Slide (Code cell)
#
# Set to Slide

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.show()

# %%
{"slideshow": {"slide_type": "slide"}}

# %% [markdown]
# 4. Fragment Example (Markdown cell)
#
# This shows step-by-step bullet reveal.

# %% [markdown]
# ## Key Points
#
# - First idea
# - Second idea
# - Third idea

# %% [markdown]
# Now change each bullet to fragments by splitting into multiple cells OR use:

# %%
{"slideshow": {"slide_type": "fragment"}}

# %% [markdown]
# 5. Sub-slide (Markdown cell)
#
# Use this for vertical stacking in reveal.js

# %% [markdown]
# ## Deeper Detail
#
# This is a sub-slide under the previous topic.

# %%
{"slideshow": {"slide_type": "subslide"}}

# %% [markdown]
# 6. Math Slide (Markdown cell)

# %% [markdown]
# ## Mathematical Model
#
# \[
# f(x) = \sin(x) + \cos(x)
# \]

# %%
{"slideshow": {"slide_type": "slide"}}

# %% [markdown]
# 7. Conclusion Slide (Markdown cell)

# %% [markdown]
# ## Conclusion
#
# - JupyterLab + RISE enables reveal.js slides
# - Works directly from notebooks
# - Great for teaching and presentations
